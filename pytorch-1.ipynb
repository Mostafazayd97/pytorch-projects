# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 20
X = np.random.random(N) * 10 - 5
Y = 0.5 * X - 1 + np.random.randn(N)

# %%
plt.scatter(X,Y)

# %%
model = nn.Linear(1,1)
criterion = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

# %%
X = X.reshape(N,1)
Y = Y.reshape(N,1)

inputs = torch.from_numpy(X.astype(np.float32))
targets = torch.from_numpy(Y.astype(np.float32))

# %%
type(inputs)
# Out:
# torch.Tensor

# %%
n = 30
losses = []
for it in range(n):
  optimizer.zero_grad()
  outputs = model(inputs)
  loss = criterion(outputs, targets)
  losses.append(loss.item())
  loss.backward()
  optimizer.step()
  print(f"epoch: {it}, loss: {loss.item()}")
# Out:
# epoch: 0, loss: 3.236187696456909
# epoch: 1, loss: 2.6757547855377197
# epoch: 2, loss: 2.2826311588287354
# epoch: 3, loss: 2.004969596862793
# epoch: 4, loss: 1.8070685863494873
# epoch: 5, loss: 1.6643394231796265
# epoch: 6, loss: 1.55984628200531
# epoch: 7, loss: 1.4819210767745972
# epoch: 8, loss: 1.4225213527679443
# epoch: 9, loss: 1.3761016130447388
# epoch: 10, loss: 1.338836431503296
# epoch: 11, loss: 1.308081865310669
# epoch: 12, loss: 1.28201162815094
# epoch: 13, loss: 1.2593591213226318
# epoch: 14, loss: 1.2392460107803345
# epoch: 15, loss: 1.2210590839385986
# epoch: 16, loss: 1.2043699026107788
# epoch: 17, loss: 1.1888768672943115
# epoch: 18, loss: 1.1743652820587158
# epoch: 19, loss: 1.1606813669204712
# epoch: 20, loss: 1.147713541984558
# epoch: 21, loss: 1.1353785991668701
# epoch: 22, loss: 1.1236143112182617
# epoch: 23, loss: 1.1123721599578857
# epoch: 24, loss: 1.1016137599945068
# epoch: 25, loss: 1.0913078784942627
# epoch: 26, loss: 1.081428050994873
# epoch: 27, loss: 1.0719515085220337
# epoch: 28, loss: 1.0628583431243896
# epoch: 29, loss: 1.0541311502456665

# %%
plt.plot(losses)

# %%
predicted = model(inputs).detach().numpy()
plt.scatter(X,Y, label="Orignal Data")
plt.plot(X,predicted, label="the model")
plt.legend()
plt.show()

# %%
w = model.weight.data.numpy()
b = model.bias.data.numpy()
print(w,b)
# Out:
# [[0.48381633]] [-0.5488314]
